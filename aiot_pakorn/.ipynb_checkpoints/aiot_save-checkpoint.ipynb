# %%
# !pip install pandas
# !pip install joblib
# !pip install scikit-learn
import numpy as np
import pandas as pd
import joblib
# Out:
# Requirement already satisfied: pandas in d:\python\imc\lib\site-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in d:\python\imc\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.15.4 in d:\python\imc\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\python\imc\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\python\imc\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: joblib in d:\python\imc\lib\site-packages (1.0.1)
# Requirement already satisfied: scikit-learn in d:\python\imc\lib\site-packages (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in d:\python\imc\lib\site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\python\imc\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in d:\python\imc\lib\site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in d:\python\imc\lib\site-packages (from scikit-learn) (1.19.5)

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pd.read_csv(url, names=names)
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
test_size = 0.33
seed = 7
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# Fit the model on training set
model = LogisticRegression(solver='lbfgs', max_iter=1000)
model.fit(X_train, Y_train)
# save the model to disk
filename = 'finalized_model.sav'
joblib.dump(model, filename)
# Out:
# ['finalized_model.sav']
